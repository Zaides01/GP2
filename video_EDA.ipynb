# %% [markdown]
# # Предобработка

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('df_video.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12870 entries, 0 to 12869
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id_x                 12870 non-null  int64
#  1   owner_id             12870 non-null  int64
#  2   group_name           12870 non-null  object
#  3   title                12870 non-null  object
#  4   description_x        9805 non-null   object
#  5   duration             12870 non-null  int64
#  6   date                 12870 non-null  int64
#  7   views                12870 non-null  int64
#  8   comments             12869 non-null  float64
#  9   can_like             12870 non-null  int64
#  10  can_repost           12870 non-null  int64
#  11  can_dislike          12870 non-null  int64
#  12  is_pinned            12870 non-null  bool
#  13  album_video_percent  12870 non-null  float64
#  14  top_comment_text     1736 non-null   object
#  15  id_y                 12770 non-null  float64
#  16  description_y        12610 non-null  object
#  17  members_count        12770 non-null  float64
#  18  activity             12770 non-null  object
#  19  status               7524 non-null   object
#  20  site                 8073 non-null   object
#  21  name                 12770 non-null  object
#  22  screen_name          12770 non-null  object
#  23  verified             12770 non-null  float64
# dtypes: bool(1), float64(5), int64(8), object(10)
# memory usage: 2.3+ MB

# %%
df.describe()
# Out:
#                id_x      owner_id      duration          date         views  \
# count  1.287000e+04  1.287000e+04  12870.000000  1.287000e+04  1.287000e+04
# mean   4.251554e+08  1.221938e+08   1366.410490  1.621940e+09  7.296571e+05
# std    9.111958e+07  8.937285e+07   1854.246604  1.153964e+08  2.808595e+06
# min    1.676794e+07  3.785000e+03      0.000000  1.201776e+09  1.000000e+00
# 25%    4.562393e+08  1.415705e+06     62.000000  1.541598e+09  2.417750e+03
# 50%    4.562400e+08  1.316070e+08    524.000000  1.675235e+09  4.536700e+04
# 75%    4.562419e+08  2.114370e+08   2153.000000  1.698410e+09  4.012842e+05
# max    4.562733e+08  2.000324e+09  32981.000000  1.741120e+09  1.900318e+08
#
#             comments      can_like  can_repost  can_dislike  \
# count   12869.000000  12870.000000     12870.0      12870.0
# mean      269.475717      0.998990         1.0          1.0
# std      2586.204142      0.031767         0.0          0.0
# min         0.000000      0.000000         1.0          1.0
# 25%         0.000000      1.000000         1.0          1.0
# 50%         8.000000      1.000000         1.0          1.0
# 75%        80.000000      1.000000         1.0          1.0
# max    173034.000000      1.000000         1.0          1.0
#
#        album_video_percent          id_y  members_count      verified
# count         12870.000000  1.277000e+04   1.277000e+04  12770.000000
# mean             67.367764  1.217611e+08   1.538171e+06      0.589977
# std              37.680896  8.602318e+07   8.884629e+05      0.491857
# min               0.000000  1.415705e+06   9.319200e+04      0.000000
# 25%              34.350000  1.415705e+06   5.322700e+05      0.000000
# 50%              64.370000  1.316070e+08   1.615033e+06      1.000000
# 75%              96.860000  2.114370e+08   2.450830e+06      1.000000
# max             500.000000  2.211304e+08   3.005383e+06      1.000000

# %%
df.head()
# Out:
#         id_x   owner_id     group_name  \
# 0  456239756  211229778  Женский форум
# 1  456239748  211229778  Женский форум
# 2  456239738  211229778  Женский форум
# 3  456239719  211229778  Женский форум
# 4  456239713  211229778  Женский форум
#
#                                               title  \
# 0                                 Женский Форум #79
# 1               Женский Форум #78 | Алексей Смирнов
# 2                                 Женский Форум #77
# 3     Женский Форум #76 | Ольга Бузова | Новогодний
# 4  Женский Форум #75 | Александр Рогов | Новогодний
#
#                                        description_x  duration        date  \
# 0  Сделай подарок любимым, а МТС Live подарит теб...      4000  1740042000
# 1  Получайте повышенный кешбэк с МТС Premium в се...      3385  1738832400
# 2  Технологии флагманов, премиальный дизайн, неве...      3993  1738054800
# 3  С VoiceTech от МТС не нужно быть айтишником, ч...      4574  1735549200
# 4  Еще больше полезных новостей в сообществе Ozon...      4055  1735376400
#
#      views  comments  can_like  ...         top_comment_text         id_y  \
# 0  5395319     975.0         1  ...  ❤️❤️❤️любимки . Смотрим  211229778.0
# 1  5364194     776.0         1  ...    золотистая барабулька  211229778.0
# 2  4543591     780.0         1  ...                   Первая  211229778.0
# 3  5911643    1940.0         1  ...    новогодняя барабулька  211229778.0
# 4  4014250     891.0         1  ...    новогодняя барабулька  211229778.0
#
#                                        description_y  members_count  \
# 0  Шоу, в котором четыре девушки дают советы по л...       706751.0
# 1  Шоу, в котором четыре девушки дают советы по л...       706751.0
# 2  Шоу, в котором четыре девушки дают советы по л...       706751.0
# 3  Шоу, в котором четыре девушки дают советы по л...       706751.0
# 4  Шоу, в котором четыре девушки дают советы по л...       706751.0
#
#         activity  status                                               site  \
# 0  Шоу, передача     NaN  https://www.youtube.com/channel/UCXDerjAwOSH30...
# 1  Шоу, передача     NaN  https://www.youtube.com/channel/UCXDerjAwOSH30...
# 2  Шоу, передача     NaN  https://www.youtube.com/channel/UCXDerjAwOSH30...
# 3  Шоу, передача     NaN  https://www.youtube.com/channel/UCXDerjAwOSH30...
# 4  Шоу, передача     NaN  https://www.youtube.com/channel/UCXDerjAwOSH30...
#
#             name screen_name verified
# 0  Женский Форум   zhenforum      1.0
# 1  Женский Форум   zhenforum      1.0
# 2  Женский Форум   zhenforum      1.0
# 3  Женский Форум   zhenforum      1.0
# 4  Женский Форум   zhenforum      1.0
#
# [5 rows x 24 columns]

# %%
df['date'] = pd.to_datetime(df['date'], unit='s')
df['can_like'] = df['can_like'].astype(bool)
df['verified'] = df['verified'].astype(bool)
df['can_repost'] = df['can_repost'].astype(bool)
df['can_dislike'] = df['can_dislike'].astype(bool)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12870 entries, 0 to 12869
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id_x                 12870 non-null  int64
#  1   owner_id             12870 non-null  int64
#  2   group_name           12870 non-null  object
#  3   title                12870 non-null  object
#  4   description_x        9805 non-null   object
#  5   duration             12870 non-null  int64
#  6   date                 12870 non-null  datetime64[ns]
#  7   views                12870 non-null  int64
#  8   comments             12869 non-null  float64
#  9   can_like             12870 non-null  bool
#  10  can_repost           12870 non-null  bool
#  11  can_dislike          12870 non-null  bool
#  12  is_pinned            12870 non-null  bool
#  13  album_video_percent  12870 non-null  float64
#  14  top_comment_text     1736 non-null   object
#  15  id_y                 12770 non-null  float64
#  16  description_y        12610 non-null  object
#  17  members_count        12770 non-null  float64
#  18  activity             12770 non-null  object
#  19  status               7524 non-null   object
#  20  site                 8073 non-null   object
#  21  name                 12770 non-null  object
#  22  screen_name          12770 non-null  object
#  23  verified             12870 non-null  bool
# dtypes: bool(5), datetime64[ns](1), float64(4), int64(4), object(10)
# memory usage: 1.9+ MB

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12865    False
# 12866    False
# 12867    False
# 12868    False
# 12869    False
# Length: 12870, dtype: bool

# %%
df.loc[df.duplicated()]
# Out:
#           id_x   owner_id group_name  \
# 277  456239463  209976560   LABELCOM
#
#                                                  title  \
# 277  Что было дальше? - ЧТО БЫЛО ДАЛЬШЕ? || ТИЗЕР Н...
#
#                                          description_x  duration  \
# 277  ШЕСТЬ приколдесных вкусов энергетика TORNADO с...        72
#
#                    date  views  comments  can_like  ...  \
# 277 2023-01-23 12:34:46  84357       1.0      True  ...
#
#                top_comment_text         id_y                  description_y  \
# 277  Фу. Такой сраный панкрок😭🤮  209976560.0  ОФИЦИАЛЬНАЯ СТРАНИЦА LABELCOM
#
#      members_count activity  status                      site      name  \
# 277      1618608.0     Юмор     NaN  http://mediumquality.ru/  LABELCOM
#
#     screen_name verified
# 277    labelcom     True
#
# [1 rows x 24 columns]

# %%
df = df.drop_duplicates()

# %% [markdown]
# # Анализ и визуализация на таргет

# %%
#наш таргет - количество просмотров
print(df['views'].isnull().sum())
print(df['views'].min())
print(df['views'].max())
# Out:
# 0
# 1
# 190031826

# %% [markdown]
# Нет пропусков в кол-вах просмотров, мин 1, макс 190.031.826

# %%
plt.figure(figsize=(10, 5))
plt.hist(df['views'],bins=75, color='skyblue')
plt.xlabel('Просмотры')
plt.ylabel('Frequency')
plt.title('Распределение просмотров видео')
plt.show()

# %% [markdown]
# Видим, что есть выбросы

# %%
#до удаления выбросов
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.boxplot(df['views'])
plt.ylabel('Просмотры')

plt.subplot(1, 2, 2)
plt.hist(df['views'], bins=75, color='skyblue')
plt.xlabel('Просмотры')
plt.ylabel('Frequency')
plt.title('Распределение просмотров видео')
plt.show()

Q1 = df['views'].quantile(0.25)
Q3 = df['views'].quantile(0.75)
IQR = Q3 - Q1

# Границы дл экстремальных выбросов
lower_line = Q1 - 3 * IQR
upper_line = Q3 + 3 * IQR

df_filtered = df[(df['views'] >= lower_line) & (df['views'] <= upper_line)]

# после удаления выбросов
plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
plt.boxplot(df_filtered['views'])
plt.ylabel('Просмотры')

plt.subplot(1, 2, 2)
plt.hist(df_filtered['views'], bins=75, color='skyblue')
plt.xlabel('Просмотры')
plt.ylabel('Frequency')
plt.title('Распределение просмотров видео')
plt.show()

# %%
print(f"Изначальная статистика:\n{df['views'].describe()}")
print(f"\nСтатистика после удаления выбросов:\n{df_filtered['views'].describe()}")
# Out:
# Изначальная статистика:
# count    1.286900e+04
# mean     7.297072e+05
# std      2.808698e+06
# min      1.000000e+00
# 25%      2.417000e+03
# 50%      4.535500e+04
# 75%      4.013760e+05
# max      1.900318e+08
# Name: views, dtype: float64
#
# Статистика после удаления выбросов:
# count    1.132500e+04
# mean     1.811721e+05
# std      3.315023e+05
# min      1.000000e+00
# 25%      1.628000e+03
# 50%      2.407900e+04
# 75%      1.841620e+05
# max      1.598239e+06
# Name: views, dtype: float64

# %%
#Строим карту корреляции от количественных признаков
plt.figure(figsize=(10, 8))
correlation_matrix = df_filtered[['views',  'comments', 'duration', 'members_count', 'album_video_percent']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Карта корреляции')
plt.show()

# %%
#Строим графики рассеяния для признаков, влияющих на просмотры
plt.figure(figsize=(5, 5))
plt.scatter(df_filtered['duration'], df_filtered['views'],color='green', alpha=0.3)
plt.xlabel('Длительность')
plt.ylabel('Просмотры')
plt.title('Зависимость просмотров от длительности видео')
plt.show()

plt.figure(figsize=(5, 5))
plt.scatter(df_filtered['comments'], df_filtered['views'], alpha=0.3)
plt.xlabel('Комментарии')
plt.ylabel('Просмотры')
plt.title('Зависимость просмотров от кол-ва комментариев')
plt.show()

plt.figure(figsize=(5, 5))
plt.scatter(df_filtered['members_count'], df_filtered['views'],color='orange', alpha=0.3)
plt.xlabel('Подписчики')
plt.ylabel('Просмотры')
plt.title('Зависимость просмотров от кол-ва подписчиков')
plt.show()

# %% [markdown]
# **Графики получились скученные, нужно посмотреть на выбросы**

# %%
plt.figure(figsize=(15, 5))
plt.hist(df['duration'], bins=75, color='green')
plt.xlabel('Длительность')
plt.ylabel('Frequency')
plt.title('Распределение длительности видео')
plt.show()

plt.figure(figsize=(15, 5))
plt.hist(df['comments'], bins=75, color='blue')
plt.xlabel('Кол-во комментариев')
plt.ylabel('Frequency')
plt.title('Распределение кол-ва комментариев')
plt.show()

plt.figure(figsize=(15, 5))
plt.hist(df['members_count'], bins=200, color='orange')
plt.xlabel('Подписчики')
plt.ylabel('Frequency')
plt.title('Распределение кол-ва подписчиков')
plt.show()

# %%
#убираем выбросы в длительности в количестве комментариев
Q1_1 = df_filtered[['duration','comments']].quantile(0.25)
Q3_1 = df_filtered[['duration','comments']].quantile(0.75)
IQR_1 = Q3_1 - Q1_1

lower_line_1 = Q1_1 - 3 * IQR_1
upper_line_1 = Q3_1 + 3 * IQR_1

df_filter = df_filtered[
    (df_filtered['duration'] >= lower_line_1['duration']) &
    (df_filtered['duration'] <= upper_line_1['duration']) &
    (df_filtered['comments'] >= lower_line_1['comments']) &
    (df_filtered['comments'] <= upper_line_1['comments'])
]

# %%
#еще раз строим графики рассеяния
plt.figure(figsize=(5, 5))
plt.scatter(df_filter['duration'], df_filter['views'],color='green', alpha=0.3)
plt.xlabel('Длительность')
plt.ylabel('Просмотры')
plt.title('Зависимость просмотров от длительности видео')
plt.show()

plt.figure(figsize=(5, 5))
plt.scatter(df_filter['comments'], df_filter['views'], alpha=0.3)
plt.xlabel('Комментарии')
plt.ylabel('Просмотры')
plt.title('Зависимость просмотров от кол-ва комментариев')
plt.show()

plt.figure(figsize=(5, 5))
plt.scatter(df_filter['members_count'], df_filter['views'],color='orange', alpha=0.3)
plt.xlabel('Подписчики')
plt.ylabel('Просмотры')
plt.title('Зависимость просмотров от кол-ва подписчиков')
plt.show()

# %%
#Строим карту корреляции от бинарных признаков
plt.figure(figsize=(10, 8))
correlation_matrix = df_filter[['views','can_like', 'can_repost', 'can_dislike', 'is_pinned', 'verified']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Карта корреляции')
plt.show()

# %%
mean = df_filter[['can_repost', 'can_dislike', 'is_pinned']].mean()
print(mean)

var = df_filter[['can_repost', 'can_dislike', 'is_pinned']].var()
print(var)
# Out:
# can_repost     1.0
# can_dislike    1.0
# is_pinned      0.0
# dtype: float64
# can_repost     0.0
# can_dislike    0.0
# is_pinned      0.0
# dtype: float64

# %% [markdown]
# Видим , что все столбцы в 'can_repost', 'can_dislike' имеют значение 1, а в столбце 'is_pinned' нет значений вообще
#
# **Поэтому на графике heatmap пустые секции**

# %%
#Строим графики рассеяния для признаков, влияющих на просмотры
plt.figure(figsize=(5, 5))
plt.scatter(df_filter['verified'], df_filter['views'],color='salmon', alpha=0.2)
plt.xlabel('Есть верификация сообщества')
plt.ylabel('Просмотры')
plt.title('Зависимость просмотров от наличия галочки верификации')
plt.show()

# %% [markdown]
# Видим, что при наличие галочки верификации распределение большого количесво просмотров более плотное, чем когда верификации канала нет

# %%
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
sns.boxplot(x='group_name', y='views', data=df_filter)
plt.xticks(rotation=45, ha='right')
plt.ylabel('Просмотры')
plt.xlabel('Сообщества')
plt.title('Боксплот для просмотров по сообществам')

plt.subplot(1, 2, 2)
sns.boxplot(x='activity', y='views', data=df_filter)
plt.xticks(rotation=45, ha='right')
plt.ylabel('Просмотры')
plt.xlabel('Тип активности')
plt.title('Боксплот для просмотров по типу активности')

plt.show()

# %%
pd.options.display.float_format = '{:,.0f}'.format

top_5_groups = df_filter.groupby('group_name')['views'].mean().sort_values(ascending=False).head(5)
print("Топ-5 популярных сообществ по средним просмотрам:\n")
print(top_5_groups)

top_3_activities = df_filter.groupby('activity')['views'].mean().sort_values(ascending=False).head(3)
print("\nТоп-3 популярных активности по средним просмотрам:\n")
print(top_3_activities)
# Out:
# Топ-5 популярных сообществ по средним просмотрам:
#
# group_name
# Женский форум                    1,102,809
# Комьюнити                          737,150
# Hardcore Fighting Championship     608,834
# Парковка                           583,846
# Стрелец-Молодец                    525,995
# Name: views, dtype: float64
#
# Топ-3 популярных активности по средним просмотрам:
#
# activity
# Спортивная организация   608,834
# Автомобили               281,508
# Юмор                     272,479
# Name: views, dtype: float64

# %%
#смотрим средние просмотры в каждом типе активности в разбивке по длительности роликов
bins = [0, 1800, 3600, 7200, float('inf')]
labels = ['Короткие', 'Средние', 'Длинные', 'Очень длинные']
df_filter['duration_category'] = pd.cut(df_filter['duration'], bins=bins, labels=labels)

for activity in df_filter['activity'].unique():
    df_1 = df_filter[df_filter['activity'] == activity]
    avg_views = df_1.groupby('duration_category')['views'].mean()
    print(f"\nСредние просмотры в активности '{activity}' в разбивке по длительности видео:\n{avg_views}")
# Out:
# Средние просмотры в активности 'Шоу, передача' в разбивке по длительности видео:
# duration_category
# Короткие        152,551
# Средние         273,179
# Длинные         190,970
# Очень длинные       NaN
# Name: views, dtype: float64
#
# Средние просмотры в активности 'nan' в разбивке по длительности видео:
# duration_category
# Короткие        NaN
# Средние         NaN
# Длинные         NaN
# Очень длинные   NaN
# Name: views, dtype: float64
#
# Средние просмотры в активности 'Юмор' в разбивке по длительности видео:
# duration_category
# Короткие        115,671
# Средние         478,573
# Длинные         726,892
# Очень длинные       NaN
# Name: views, dtype: float64
#
# Средние просмотры в активности 'Комик' в разбивке по длительности видео:
# duration_category
# Короткие         15,019
# Средние         729,251
# Длинные         438,054
# Очень длинные       NaN
# Name: views, dtype: float64
#
# Средние просмотры в активности 'Дом культуры' в разбивке по длительности видео:
# duration_category
# Короткие        22,603
# Средние         25,707
# Длинные         45,792
# Очень длинные      NaN
# Name: views, dtype: float64
#
# Средние просмотры в активности 'Автомобили' в разбивке по длительности видео:
# duration_category
# Короткие        222,345
# Средние         324,161
# Длинные             NaN
# Очень длинные       NaN
# Name: views, dtype: float64
#
# Средние просмотры в активности 'Телеканал' в разбивке по длительности видео:
# duration_category
# Короткие        206,196
# Средние             NaN
# Длинные             NaN
# Очень длинные       NaN
# Name: views, dtype: float64
#
# Средние просмотры в активности 'Блогер' в разбивке по длительности видео:
# duration_category
# Короткие         43,756
# Средние          34,455
# Длинные         278,190
# Очень длинные       NaN
# Name: views, dtype: float64
#
# Средние просмотры в активности 'Спортивная организация' в разбивке по длительности видео:
# duration_category
# Короткие        451,461
# Средние         393,634
# Длинные         756,041
# Очень длинные       NaN
# Name: views, dtype: float64
#
# Средние просмотры в активности 'Музыка' в разбивке по длительности видео:
# duration_category
# Короткие         49,605
# Средние         143,107
# Длинные         145,820
# Очень длинные       NaN
# Name: views, dtype: float64
# <ipython-input-42-a73ba694cfd3>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filter['duration_category'] = pd.cut(df_filter['duration'], bins=bins, labels=labels)
# <ipython-input-42-a73ba694cfd3>:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avg_views = df_1.groupby('duration_category')['views'].mean()

# %% [markdown]
# # Анализ трендов

# %%
df_trends = pd.read_csv('videos_trend_pars.csv')

# %%
from datetime import datetime

dttm_pars = datetime(2025, 3, 4)  # дата парсинга трендов
dttm = dttm_pars - pd.Timedelta(days=5)  # предположительно, в тренды попадают видео за последние 5 дней

# %%
df_filter['title'] = df_filter['title'].str.lower().str.strip()
df_trends['title'] = df_trends['title'].str.lower().str.strip()

df_last_5 = df_filter[df_filter['date'] >= dttm]

peresech = pd.merge(
    df_last_5[['title', 'views', 'date']],
    df_trends[['title', 'views']], on='title', how='inner', suffixes=('_main', '_trends'))

peresech = peresech.sort_values(by='views_main', ascending=False)

print(f"Найдено пересечений: {len(peresech)}")
peresech.head(10)
# Out:
# Найдено пересечений: 1
# <ipython-input-54-ac838195e7d9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filter['title'] = df_filter['title'].str.lower().str.strip()
#                                    title  views_main                date  \
# 0  однажды в россии: свободные отношения      294572 2025-03-02 10:00:34
#
#          views_trends
# 0  232 тыс просмотров

# %% [markdown]
# Нашли одно шоу, которое попало в тренды за последние 5 дней, кол-во просмотров 232 тыс , что относительно хорошие показатели по популярности среди пользователей
